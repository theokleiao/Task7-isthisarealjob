# %%
import re
import pandas as pd

# %%
posts = pd.read_csv("posts.csv")

# %%
posts
# Out:
#       id  user_id                                               body  \
# 0      3        4                #world is greater than #good things
# 1    128       12  You are invited for a JOB INTERVIEW on THUR 23...
# 2      7        6  Global Resources invites u for Aptitude test/b...
# 3      8        7  Who knew a hug could win you free VVIP tickets...
# 4      9        6  Dps invites u for an interview chat to work wi...
# ..   ...      ...                                                ...
# 535  554      365  <p>Please is this real?</p><p><br></p><p>WE AR...
# 536  555      365  <p>Please is this real?</p><p><br></p><p>WE AR...
# 537  556      637                             <p>\r\n</p><p><br></p>
# 538  557      637                             <p>\r\n</p><p><br></p>
# 539  558      674                            <p>Hmm, there there</p>
#
#               created_at           updated_at  \
# 0    2018-02-27 23:14:37  2018-02-27 23:14:37
# ...

# %%
posts.drop(['updated_at', 'deleted_at', 'verified', 'pictures', 'created_at', 'hashtags'],axis=1, inplace=True)

# %%
posts
# Out:
#       id  user_id                                               body  \
# 0      3        4                #world is greater than #good things
# 1    128       12  You are invited for a JOB INTERVIEW on THUR 23...
# 2      7        6  Global Resources invites u for Aptitude test/b...
# 3      8        7  Who knew a hug could win you free VVIP tickets...
# 4      9        6  Dps invites u for an interview chat to work wi...
# ..   ...      ...                                                ...
# 535  554      365  <p>Please is this real?</p><p><br></p><p>WE AR...
# 536  555      365  <p>Please is this real?</p><p><br></p><p>WE AR...
# 537  556      637                             <p>\r\n</p><p><br></p>
# 538  557      637                             <p>\r\n</p><p><br></p>
# 539  558      674                            <p>Hmm, there there</p>
#
#                                                  title         author  \
# ...

# %%
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/naeamakachalokwu/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sent_tokenized = [sent for sent in nltk.sent_tokenize("""
                        You are invited for a JOB INTERVIEW on THUR 23RD NOV, 9am @ 4 Alara St, off Commercial Avenue Sabo-Yaba, Lagos. 
                        Details in ur mailbox.www.hyinsco.com.ng.
                        """)]

# %%
words_tokenized = [word for word in nltk.word_tokenize(sent_tokenized[0])]

# %%
filtered = [word for word in words_tokenized if re.search('[a-zA-Z]', word)]

# %%
filtered
# Out:
# ['You',
#  'are',
#  'invited',
#  'for',
#  'a',
#  'JOB',
#  'INTERVIEW',
#  'on',
#  'THUR',
#  '23RD',
#  'NOV',
#  '9am',
#  'Alara',
#  'St',
#  'off',
#  'Commercial',
#  'Avenue',
#  'Sabo-Yaba',
#  'Lagos']

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer("english")

# let's observe words without stemming
print("Without stemming: ", filtered)
# Out:
# Without stemming:  ['You', 'are', 'invited', 'for', 'a', 'JOB', 'INTERVIEW', 'on', 'THUR', '23RD', 'NOV', '9am', 'Alara', 'St', 'off', 'Commercial', 'Avenue', 'Sabo-Yaba', 'Lagos']

# %%
stemmed_words = [stemmer.stem(word) for word in filtered]
# now let's check out after stemming
print("After stemming:   ", stemmed_words)
# Out:
# After stemming:    ['you', 'are', 'invit', 'for', 'a', 'job', 'interview', 'on', 'thur', '23rd', 'nov', '9am', 'alara', 'st', 'off', 'commerci', 'avenu', 'sabo-yaba', 'lago']
